# %% [markdown]
# # `ASSIGNMENT`   WebScraping 2

# %% [markdown]
# ## Problem 1

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import requests

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

import time

def data_analyst_scrapes(url):

    opts = Options()
    driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)

    opts.add_argument("user-agent=Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36")

    #url = "https://www.naukri.com/"

    driver.get(url)

    driver.find_element_by_id('qsb-keyword-sugg').send_keys('Data Analyst')
    driver.find_element_by_id('qsb-location-sugg').send_keys('Bangalore')

    driver.find_element_by_class_name('btn').click()
    
    time.sleep(0.7)
    
    # scraping the data:

    job_titles, job_company = [],[]

    job_location, job_exp_req, job_sal = [],[],[]

    for title in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")[:10]:
        job_titles.append(title.text)

    for company_name in driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")[:10]:
        job_company.append(company_name.text)

    for i,value in enumerate(driver.find_elements_by_xpath("//span[@class='ellipsis fleft fs12 lh16']")):
            if i%3 == 0:
                job_sal.append(value.text)

            if i%3 == 1:
                job_location.append(value.text)

            if i%3 ==2:
                job_exp_req.append(value.text)
                
            if i>28:
                break
                
    
    driver.quit()

    df = pd.DataFrame({'job_title':job_titles,'job_company':job_company,'job_locations':job_location,'experience_req':job_exp_req,'job_salary':job_sal})

    return df

data_analyst_scrapes('https://www.naukri.com/')
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Admin\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
# <ipython-input-112-100f4a79e280>:15: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)
#                                            job_title  \
# 0  Immediate opening For Data Scientist/Data Analyst
# 1                               Hiring Data Analysts
# 2                  Purchase Executive - Data Analyst
# 3                                       Data Analyst
# 4                                       Data Analyst
# 5               Data Analyst ( Predictive Modelling)
# 6                      Data Scientist / Data Analyst
# 7                                  NiFi Data Analyst
# 8                                  NiFi Data Analyst
# 9    Product Manager - Data Scientist / Data Analyst
#
#                                          job_company            job_locations  \
# 0  CAIA-Center For Artificial Intelligence & Adva...  3,50,000 - 4,50,000 PA.
# 1                  Flipkart Internet Private Limited  3,00,000 - 6,00,000 PA.
# 2                                      Columbia Asia            Not disclosed
# 3           Cognizant Technology Solutions India Ltd            Not disclosed
# 4           Cognizant Technology Solutions India Ltd            Not disclosed
# 5                                       AVE-Promagne            Not disclosed
# 6                          Altimetrik India Pvt. Ltd            Not disclosed
# 7        Capgemini Technology Services India Limited            Not disclosed
# 8        Capgemini Technology Services India Limited            Not disclosed
# 9                              Fortune HR Consultant            Not disclosed
#
#                         experience_req job_salary
# 0  Chennai, Pune, Bengaluru, Hyderabad    0-3 Yrs
# 1                            Bengaluru    2-5 Yrs
# 2              Bengaluru(Indira Nagar)    3-5 Yrs
# 3                            Bengaluru    3-6 Yrs
# 4                            Bengaluru    2-3 Yrs
# 5                            Bengaluru    2-5 Yrs
# 6                            Bengaluru    3-8 Yrs
# 7                            Bengaluru    4-6 Yrs
# 8                            Bengaluru    6-9 Yrs
# 9                            Bengaluru    2-7 Yrs

# %% [markdown]
# ## Problem 2

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import requests

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

import time


def data_scientist_job_scrapes_temp(url):
    opts = Options()
    driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)

    opts.add_argument("user-agent=Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36")

    #url = "https://www.naukri.com/"

    job_titles, job_company = [],[]

    job_location, job_exp_req, job_sal = [],[],[]


    driver.get(url)

    driver.find_element_by_id('qsb-keyword-sugg').send_keys('Data Scientist')
    driver.find_element_by_id('qsb-location-sugg').send_keys('Bangalore')

    driver.find_element_by_class_name('btn').click()


    time.sleep(1)


    window_before = driver.window_handles[0]


    for block in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")[:10]:
        block.click()
        window_after = driver.window_handles[-1]

        driver.switch_to.window(window_after)

        time.sleep(1)
        
        try:
        
            job_titles.append(driver.find_element_by_class_name('jd-header-title').text)
            job_company.append(driver.find_element_by_xpath("//div[@class='jd-header-comp-name']/a").text)
            job_exp_req.append(driver.find_element_by_xpath("//div[@class='left']/div/span").text)
            job_sal.append(driver.find_element_by_xpath("//div[@class='salary']/span").text)

            location_list = []
            for element in driver.find_elements_by_xpath("//span[@class='location ']/a"):
                location_list.append(element.text)

            job_location.append(','.join(location_list))
                        
        except:
            
            job_titles.append(driver.find_element_by_xpath("//h1[@class='av-special-heading-tag ']").text)
            job_company.append(driver.find_element_by_xpath("//p[@class='cpName f14']").text)
            job_exp_req.append(driver.find_element_by_xpath("//span[@class='slide-meta-exp pull-left']").text)
            job_sal.append(driver.find_element_by_xpath("//span[@class='slide-meta-sal sal pull-left ']").text)


            job_location.append(driver.find_element_by_xpath("//span[@class='jobs-icon loc']").text)
                
        driver.close()

        time.sleep(1)

        driver.switch_to.window(window_before)
        
    df = pd.DataFrame({'job_title':job_titles,'job_company':job_company,'job_locations':job_location,'experience_req':job_exp_req,'job_salary':job_sal})
    
    return df


result = data_scientist_job_scrapes_temp('https://www.naukri.com/')

result.to_csv('data_scientist_scrapes.csv',index=None)

result
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Admin\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
# <ipython-input-276-e566570792b9>:5: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)
#                                            job_title  \
# 0  Immediate opening For Data Scientist/Data Analyst
# 1  Lead Data Scientist - Machine Learning/ Data M...
# 2                      Data Scientist / Data Analyst
# 3           Explore job openings on Data Scientist!!
# 4  Senior Principal Software Engineer - IT ( Data...
# 5                              Senior Data Scientist
# 6             Machine Learning Lead / Data Scientist
# 7                      GLOBAL MEDICAL DATA SCIENTIST
# 8                           Principal Data Scientist
# 9                 AI Resident – Data Scientist – NLP
#
#                                          job_company  \
# 0  CAIA-Center For Artificial Intelligence & Adva...
# 1                       Wrackle Technologies Pvt Ltd
# 2                          Altimetrik India Pvt. Ltd
# 3                          Bristlecone India Limited
# 4   Dell International Services IndiaPrivate Limited
# 5                                   Philips Lighting
# 6                  Morgan Stanley Advantage Services
# 7            GlaxoSmithKline Pharmaceuticals Limited
# 8                                   Philips Lighting
# 9                Shell India Markets Private Limited
#
#                       job_locations                     experience_req  \
# 0  Chennai,Pune,Bengaluru,Hyderabad                        0 - 3 years
# 1                         Bengaluru                       6 - 11 years
# 2                         Bengaluru                        3 - 8 years
# 3             Pune,Mumbai,Bengaluru                        4 - 9 years
# 4                         Bengaluru                      10 - 15 years
# 5                         Bengaluru                       6 - 10 years
# 6                         Bengaluru                        4 - 6 years
# 7                                    from 5 to 9 year(s) of Experience
# 8                         Bengaluru                      10 - 15 years
# 9                                    from 3 to 5 year(s) of Experience
#
#                    job_salary
# 0  ₹ 3,50,000 - 4,50,000 P.A.
# 1               Not Disclosed
# 2               Not Disclosed
# 3  ₹ 3,00,000 - 8,00,000 P.A.
# 4               Not Disclosed
# 5               Not Disclosed
# 6               Not Disclosed
# 7  Not Disclosed by Recruiter
# 8               Not Disclosed
# 9  Not Disclosed by Recruiter

# %% [markdown]
# ## Problem 3

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import requests

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

import time



def data_filter_scrape(url):

    opts = Options()
    driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)

    opts.add_argument("user-agent=Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36")

    #url = "https://www.naukri.com/"

    driver.get(url)

    driver.find_element_by_id('qsb-keyword-sugg').send_keys('Data Scientist')


    driver.find_element_by_class_name('btn').click()
    
    time.sleep(2)
    
    
    driver.find_element_by_xpath("//label[@for='chk-Delhi/NCR-cityType-']/i").click()     # filter click for location

    time.sleep(5)
    
    driver.find_element_by_xpath("//label[@for='chk-3-6 Lakhs-ctcFilter-']/i").click()     # filter click for salary range
    
    time.sleep(2)
    
    
    # scraping the data:

    job_titles, job_company = [],[]

    job_location, job_exp_req, job_sal = [],[],[]

    for title in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")[:10]:
        job_titles.append(title.text)

    for company_name in driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")[:10]:
        job_company.append(company_name.text)

    for i,value in enumerate(driver.find_elements_by_xpath("//span[@class='ellipsis fleft fs12 lh16']")):
            if i%3 == 0:
                job_exp_req.append(value.text)

            if i%3 == 1:
                job_sal.append(value.text)

            if i%3 ==2:
                job_location.append(value.text)
                
            if i>28:
                break
                
    
    driver.quit()

    df = pd.DataFrame({'job_title':job_titles,'job_company':job_company,'job_locations':job_location,'experience_req':job_exp_req,'job_salary':job_sal})

    return df

data_filter_scrape('https://www.naukri.com/')
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Admin\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
# <ipython-input-396-b34bbdd30081>:17: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)
#                                            job_title  \
# 0  Tech Mahindra Hiring For Data Scientist- Hyder...
# 1  Only Fresher / Data Scientist / Data Analyst /...
# 2  Only Fresher / Data Scientist / Data Analyst /...
# 3                                     Data Scientist
# 4                                Lead Data Scientist
# 5  Excellent opportunity For Lead Data Scientist ...
# 6                                Lead Data Scientist
# 7  Excellent opportunity For Lead Data Scientist ...
# 8                       Data Scientist/BPM/4-8 years
# 9                    Data Scientist Machine Learning
#
#                                          job_company  \
# 0                                  tech mahindra ltd
# 1                          GABA Consultancy services
# 2                          GABA Consultancy services
# 3                             Air Asia India Limited
# 4                  NEC CORPORATION INDIA PRIVATE LTD
# 5                  NEC CORPORATION INDIA PRIVATE LTD
# 6                  NEC CORPORATION INDIA PRIVATE LTD
# 7                  NEC CORPORATION INDIA PRIVATE LTD
# 8  CRESCENDO GLOBAL LEADERSHIP HIRING INDIA PRIVA...
# 9                                          Delhivery
#
#                         job_locations experience_req               job_salary
# 0                    Hyderabad, Noida        3-8 Yrs            Not disclosed
# 1           Delhi NCR, Noida, Gurgaon        0-0 Yrs  2,25,000 - 4,75,000 PA.
# 2     Delhi NCR, Greater Noida, Noida        0-0 Yrs  2,25,000 - 4,75,000 PA.
# 3                  Delhi NCR, Gurgaon        1-4 Yrs            Not disclosed
# 4  Delhi NCR, Noida(Sector-142 Noida)       9-14 Yrs            Not disclosed
# 5  Delhi NCR(Sector-142 Noida), Noida       9-14 Yrs            Not disclosed
# 6  Delhi NCR, Noida(Sector-142 Noida)       9-14 Yrs            Not disclosed
# 7  Delhi NCR(Sector-142 Noida), Noida       9-14 Yrs            Not disclosed
# 8                             Gurgaon        4-7 Yrs  5,00,000 - 8,00,000 PA.
# 9                             Gurgaon        1-3 Yrs            Not disclosed

# %% [markdown]
# ## Problem 4

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import requests

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time


def glassdoor_ds_jobs(url):
    opts = Options()
    driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)

    opts.add_argument("user-agent=Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36")

    title_l,price_l,ratings_l = [],[],[]    

    driver.get(url)


    company_l,days_l,rating_l = [],[],[]
    counter = 0

    time.sleep(2)


    driver.find_element_by_xpath("//a[@class='track-click gd-btn-locked-transparent susiLink sign-in strong nowrap']").click()
    time.sleep(2)

    driver.find_element_by_id("userEmail").send_keys('ml.prathamesh.master@gmail.com')

    driver.find_element_by_id("userPassword").send_keys("lucifer0118")

    driver.find_element_by_xpath("//button[@class='gd-ui-button minWidthBtn css-8i7bc2']").click()
    time.sleep(2)

    driver.find_elements_by_xpath("//input[@class='css-1etjok6']")[2].send_keys(Keys.CONTROL + "a")
    time.sleep(1)

    driver.find_elements_by_xpath("//input[@class='css-1etjok6']")[2].send_keys('Noida')

    driver.find_elements_by_xpath("//input[@class='css-1etjok6']")[1].send_keys('Data Scientist')

    driver.find_element_by_xpath("//button[@class='gd-ui-button ml-std col-auto SearchStyles__newSearchButton css-iixdfr']").click()
    time.sleep(2)

    for i in driver.find_elements_by_xpath("//div[@class='d-flex align-items-end pl-std css-mi55ob']")[:10]:
        days_l.append(i.text)

    for i in driver.find_elements_by_xpath("//a[@class=' css-10l5u4p e1n63ojh0 jobLink']/span")[:10]:
        company_l.append(i.text)

    for i in driver.find_elements_by_class_name("compactStars")[:10]:
        rating_l.append(i.text)


    df = pd.DataFrame(list(zip(company_l,rating_l,days_l)),columns=['comapny','rating','days_since_posted'])

    return df

res_df = glassdoor_ds_jobs('https://www.glassdoor.co.in/index.htm')

res_df
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Admin\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
# <ipython-input-563-51acfed64997>:15: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)
#                         comapny rating days_since_posted
# 0                     Microsoft    4.4                8d
# 1             CMP Digital Media    3.5                9d
# 2                       Dürr AG    3.7                8d
# 3               Dürr Somac GmbH    4.4                7d
# 4                Biz2Credit Inc      5              30d+
# 5               JNtech Networks    4.3                3d
# 6  Salasar New Age Technologies    3.9              30d+
# 7  Salasar New Age Technologies    3.3              30d+
# 8                      Techlive      3              30d+
# 9               SearchUrCollege      4              30d+

# %%
res_df.to_csv('glassdoor_ds_jobs.csv')

# %% [markdown]
# ## Problem 5

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import requests

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time


def glassdoor_ds_salaries(url):

    opts = Options()
    driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)

    opts.add_argument("user-agent=Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36")

    title_l,price_l,ratings_l = [],[],[]    

    driver.get(url)


    avg_sal_l,min_sal_l,max_sal_l,company_l = [],[],[],[]
    counter = 0

    time.sleep(2)


    driver.find_element_by_class_name("keyword").send_keys('Data Scientist')

    driver.find_element_by_class_name("loc").send_keys(Keys.CONTROL + 'a')

    driver.find_element_by_class_name("loc").send_keys('Noida')

    driver.find_element_by_class_name("gd-btn-mkt").click()

    time.sleep(2)

    sauce = driver.page_source

    soup = BeautifulSoup(sauce)

    for i in soup.find_all('div',attrs={'class':"col-2 d-none d-md-flex flex-row justify-content-end"})[:10]:
        avg_sal_l.append(i.text)

    for i in soup.find_all('p',attrs={'class':"d-block d-md-none m-0 css-1kuy7z7"})[:10]:
        element = i.text.strip('Range: ').split('-')
        min_sal_l.append(element[0])
        max_sal_l.append(element[1])

    for n,i in enumerate(soup.find_all('p',attrs={'class':"m-0"})[2:60]):
        if n%6 == 0:
            company_l.append(i.text)    

    df = pd.DataFrame(list(zip(company_l,avg_sal_l,min_sal_l,max_sal_l)),columns=['comapny','avg_salary','min_salary','max_salary'])

    return df


res_df = glassdoor_ds_salaries('https://www.glassdoor.co.in/Salaries/index.htm')

res_df
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Admin\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
# <ipython-input-565-b3bab1b71955>:16: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)
#                           comapny      avg_salary min_salary max_salary
# 0                       Delhivery  ₹ 12,83,026/yr     ₹705K    ₹11,495K
# 1                       Accenture  ₹ 11,19,272/yr     ₹571K     ₹2,200K
# 2                             IBM   ₹ 7,52,445/yr     ₹580K     ₹2,700K
# 3              Ericsson-Worldwide   ₹ 8,28,000/yr     ₹468K     ₹1,595K
# 4              UnitedHealth Group  ₹ 13,21,601/yr     ₹708K     ₹1,557K
# 5                Analytics Vidhya     ₹ 20,889/mo      ₹14K        ₹22K
# 6       Tata Consultancy Services   ₹ 6,33,432/yr     ₹488K     ₹1,000K
# 7  Cognizant Technology Solutions   ₹ 9,96,446/yr     ₹784K     ₹1,250K
# 8              Valiance Solutions   ₹ 7,71,320/yr     ₹496K     ₹1,138K
# 9              Vidooly Media Tech     ₹ 12,669/mo       ₹8K        ₹20K

# %%
res_df.to_csv('glassdoor_ds_job_salaries.csv')

# %% [markdown]
# ## Problem 6

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import requests

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys

import time

def sunglasses_flikpart(url):

    opts = Options()
    driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)

    opts.add_argument("user-agent=Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36")

    #url = "https://www.flipkart.com/"


    brand, desc, price, discount = [],[],[],[]
    counter = 0

    driver.get(url)


    driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']").click()  # close the login pop-up

    driver.find_element_by_xpath("//input[@class='_3704LK']").clear()
    driver.find_element_by_xpath("//input[@class='_3704LK']").send_keys('sunglasses',Keys.RETURN)  # search for sunglasses

    window_before = driver.window_handles[0]

    time.sleep(3)


    while counter < 101:

        for block in driver.find_elements_by_xpath("//img[@class='_2r_T1I']"):
            block.click()
            window_after = driver.window_handles[-1]

            driver.switch_to.window(window_after)

            time.sleep(2)

            brand.append(driver.find_element_by_class_name("G6XhRU").text)
            desc.append(driver.find_element_by_class_name("B_NuCI").text)
            price.append(driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']").text)
            discount.append(driver.find_element_by_xpath("//div[@class='_3Ay6Sb _31Dcoz pZkvcx']/span").text)    

            driver.close()

            time.sleep(2)

            driver.switch_to.window(window_before)

            counter += 1

            #print(counter)


        driver.find_elements_by_xpath("//a[@class='_1LKTO3']")[-1].click()

        time.sleep(5)


    df = pd.DataFrame(list(zip(brand,price,discount,desc)),columns=['brand','price','discount','description'])

    df.drop_duplicates(inplace=True)

    return df
    
res_df = sunglasses_flikpart('https://www.flipkart.com/')
res_df
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Admin\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
# <ipython-input-9-b8795d8c3684>:16: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)
#                brand price discount  \
# 0              hipe   ₹163  88% off
# 1         Tenebrose   ₹450  46% off
# 2    Trendy Glasses   ₹233  82% off
# 3        Phenomenal   ₹399  80% off
# 4          Fastrack   ₹663  17% off
# ..               ...   ...      ...
# 115           shadz   ₹100  83% off
# 116        Fastrack   ₹759  15% off
# 117         I Flash   ₹130  86% off
# 118      funglasses   ₹189  81% off
# 119        Fastrack   ₹659  17% off
#
#                                            description
# 0    Mirrored, UV Protection, Gradient Round Sungla...
# 1        UV Protection Sports Sunglasses (72)  (Green)
# 2    UV Protection Retro Square Sunglasses (Free Si...
# 3    UV Protection, Mirrored Retro Square Sunglasse...
# 4    Gradient, UV Protection Wayfarer Sunglasses (F...
# ..                                                 ...
# 115  UV Protection, Gradient Round Sunglasses (50) ...
# 116  UV Protection Shield Sunglasses (Free Size)  (...
# 117  Gradient, UV Protection Round Sunglasses (Free...
# 118  UV Protection, Polarized Retro Square Sunglass...
# 119  UV Protection Wayfarer Sunglasses (Free Size) ...
#
# [110 rows x 4 columns]

# %%
res_df.to_csv('100sunglasses_fk.csv')

# %% [markdown]
# ## Problem 7

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import requests

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys

import time

def iphone_reviews_flikpart(url):

    opts = Options()
    driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)

    opts.add_argument("user-agent=Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36")

    #url = "https://www.flipkart.com/"

    
    rating_l,rev_summary_l,full_summary_l = [],[],[]
    
    counter = 0

    driver.get(url)

    time.sleep(3)

    while counter < 11:


        time.sleep(2)
        
        
        for rating in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']"):
            rating_l.append(rating.text)
        
        for rev_summary in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
            rev_summary_l.append(rev_summary.text)
            
        for full_summary in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
            full_summary_l.append(full_summary.text)
             

        time.sleep(2)

        counter += 1

        driver.find_elements_by_xpath("//a[@class='_1LKTO3']")[-1].click()

        time.sleep(5)


    df = pd.DataFrame(list(zip(rating_l,rev_summary_l,full_summary_l)),columns=['ratings','review_summary','full_summary'])

    df.drop_duplicates(inplace=True)

    return df
    
res_df = iphone_reviews_flikpart('https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=1')
res_df
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Admin\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
# <ipython-input-24-4cd347251924>:16: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)
#     ratings      review_summary  \
# 0         5    Perfect product!
# 1         5       Great product
# 2         5    Perfect product!
# 3         5  Highly recommended
# 4         5    Perfect product!
# ..      ...                 ...
# 104       3       Great product
# 105       3                Nice
# 106       5                Nice
# 107       5           Just wow!
# 108       4           Brilliant
#
#                                           full_summary
# 0    Amazing phone with great cameras and better ba...
# 1    Amazing Powerful and Durable Gadget.\n\nI’m am...
# 2    It’s a must buy who is looking for an upgrade ...
# 3    iphone 11 is a very good phone to buy only if ...
# 4    Value for money❤️❤️\nIts awesome mobile phone ...
# ..                                                 ...
# 104  Terrific!!! Lucky to get this phone in first l...
# 105  Iphone 11 black 64gb is really a cool phone\n\...
# 106  Although it’s an iPhone, it doesn’t give anyth...
# 107  Apple i Phone is the best phone available in t...
# 108  use outside gives a outstanding experience ......
#
# [99 rows x 3 columns]

# %%
res_df.to_csv('100_iphone_reviews_fk.csv')

# %% [markdown]
# ## Problem 8

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import requests

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException

import time

def sneakers_flikpart(url):

    opts = Options()
    driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)

    opts.add_argument("user-agent=Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36")

    #url = "https://www.flipkart.com/"


    brand, desc, price, discount = [],[],[],[]
    counter = 0

    driver.get(url)


    driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']").click()  # close the login pop-up

    driver.find_element_by_xpath("//input[@class='_3704LK']").clear()
    driver.find_element_by_xpath("//input[@class='_3704LK']").send_keys('sneakers',Keys.RETURN)  # search for sunglasses

    window_before = driver.window_handles[0]

    time.sleep(3)


    while counter < 101:

        for block in driver.find_elements_by_xpath("//img[@class='_2r_T1I']"):
            block.click()
            window_after = driver.window_handles[-1]

            driver.switch_to.window(window_after)

            time.sleep(2)
            

            brand.append(driver.find_element_by_class_name("G6XhRU").text)
            desc.append(driver.find_element_by_class_name("B_NuCI").text)
            price.append(driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']").text)

            try:
                discount.append(driver.find_element_by_xpath("//div[@class='_3Ay6Sb _31Dcoz pZkvcx']/span").text)
            except NoSuchElementException:
                discount.append('None')


            driver.close()

            time.sleep(2)

            driver.switch_to.window(window_before)

            counter += 1

        driver.find_elements_by_xpath("//a[@class='_1LKTO3']")[-1].click()

        time.sleep(5)


    df = pd.DataFrame(list(zip(brand,price,discount,desc)),columns=['brand','price','discount','description'])

    df.drop_duplicates(inplace=True)

    return df
    
res_df = sneakers_flikpart('https://www.flipkart.com/')
res_df
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Admin\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
# <ipython-input-9-512e91873bfa>:19: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)
#              brand   price discount  \
# 0            Puma   ₹1,880  50% off
# 1          Anover     ₹349  65% off
# 2          Chevit     ₹579  70% off
# 3    Robbie jones     ₹399  60% off
# 4          Chevit     ₹249  50% off
# ..             ...     ...      ...
# 114          Puma   ₹1,924  45% off
# 115       Shoefly     ₹299  70% off
# 116     Rockfield     ₹439  56% off
# 117         Adiso     ₹399  60% off
# 118         Birde     ₹579  71% off
#
#                                            description
# 0            Puma Smash Vulc Sneakers For Men  (Black)
# 1                            Sneakers For Men  (Green)
# 2    Combo Pack of 4 Casual Sneakers With Sneakers ...
# 3    Casual Sneakers Shoes For Men Sneakers For Men...
# 4    171 Smart Tan Lace-Ups Casuals for Men Sneaker...
# ..                                                 ...
# 114  Smash v2 L White- Black Sneakers For Men  (White)
# 115  Combo Men Pack of 2 Loafers Shoes Sneakers For...
# 116                           Sneakers For Men  (Grey)
# 117             Casual shoes Sneakers For Men  (White)
# 118  Combo Pack of 4 Casual Shoes Loafers Sneakers ...
#
# [100 rows x 4 columns]

# %%
res_df.to_csv('100_sneakers_fk.csv',index=None)

# %% [markdown]
# ## Problem 9

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import requests

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

import time



def sneaker_filter_scrape_myn(url):
    opts = Options()
    driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)

    opts.add_argument("user-agent=Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36")

    
    driver.get(url)


    driver.find_element_by_xpath("//input[@value='6649.0 TO 13099.0']/following-sibling::div").click()
    time.sleep(2)
    driver.find_element_by_xpath("//input[@value='Black']/following-sibling::div").click()

    time.sleep(2)

    window_before = driver.window_handles[0]

    brand, desc, price= [],[],[]
    counter = 0

    while counter < 3:

        for block in driver.find_elements_by_xpath("//div[@class='product-sliderContainer']"):
            block.click()
            window_after = driver.window_handles[-1]

            driver.switch_to.window(window_after)

            time.sleep(2)


            brand.append(driver.find_element_by_xpath("//h1[@class='pdp-title']").text)
            desc.append(driver.find_element_by_xpath("//h1[@class='pdp-name']").text)
            price.append(driver.find_element_by_xpath("//span/strong").text)


            driver.close()

            time.sleep(2)

            driver.switch_to.window(window_before)

        counter += 1


        driver.find_element_by_xpath("//a[@rel='next']").click()

        time.sleep(5)


    df = pd.DataFrame(list(zip(brand,price,desc)),columns=['brand','price','description'])

    return df


res_df = sneaker_filter_scrape_myn('https://www.myntra.com/shoes')
res_df
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Admin\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
# <ipython-input-67-f809e4d61f10>:16: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)
#                    brand      price  \
# 0       ADIDAS Originals   Rs. 6999
# 1                   Nike  Rs. 11995
# 2                   Nike   Rs. 8495
# 3       ADIDAS Originals   Rs. 7999
# 4    KIPRUN By Decathlon   Rs. 7499
# ..                   ...        ...
# 145                 Puma   Rs. 8499
# 146       Tommy Hilfiger   Rs. 8999
# 147                 FILA   Rs. 7499
# 148                Ruosh   Rs. 6990
# 149                 Nike   Rs. 7995
#
#                                            description
# 0                             Men Casual Shoes GAZELLE
# 1           Men Black AIR ZOOM VOMERO 14 Running Shoes
# 2    Unisex Black PHANTOM GT ACADEMY DF FG/MG Footb...
# 3    Men Black Solid Stan Smith Leather Sneakers wi...
# 4                    Men Black Synthetic Running Shoes
# ..                                                 ...
# 145  Unisex Black & Orange Colourblocked Performer ...
# 146                                 Men Black Sneakers
# 147     Men Black Solid Heritage Disruptor 2A Sneakers
# 148                   Men Black Textured Leather Monks
# 149          Men Black Air Max Impact Basketball Shoes
#
# [150 rows x 3 columns]

# %%
res_df.to_csv('sneakers_black_myn.csv')

# %% [markdown]
# ## Problem 10

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import requests

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time



def laptops_i7i9_amz(url):

    opts = Options()
    driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)

    opts.add_argument("user-agent=Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36")

    title_l,price_l,ratings_l = [],[],[]    

    driver.get(url)

    counter = 0

    time.sleep(2)

    driver.find_element_by_xpath("//input[@id='twotabsearchtextbox']").send_keys('Laptop',Keys.RETURN)


    driver.find_element_by_xpath("//li[@aria-label='Intel Core i7']/span").click()
    time.sleep(2)
    driver.find_element_by_xpath("//li[@aria-label='Intel Core i9']/span").click()

    time.sleep(5)    


    while True:

        html = driver.page_source
        soup = BeautifulSoup(html)

        for i in soup.find_all('div',attrs={'data-component-type':'s-search-result'}):
            title_l.append(i.find('',attrs={'class' : 'a-size-medium a-color-base a-text-normal'}).text)

            p = i.find('span',attrs={'class':'a-price-whole'})
            if p is not None:            
                price_l.append(i.find('span',attrs={'class':'a-price-whole'}).text)
            else:
                price_l.append('?')

            z = i.find('span',attrs={'class':'a-icon-alt'})            
            if z is not None:    
                ratings_l.append(i.find('span',attrs={'class':'a-icon-alt'}).text)
            else:
                ratings_l.append('Not_rated')

            counter += 1

            if counter > 99:
                break


        if counter > 99:
            break


        driver.find_element_by_xpath("//li[@class='a-last']").click()

        time.sleep(5)


    df = pd.DataFrame(list(zip(title_l,price_l,ratings_l)),columns=['title','price','ratings'])


    return df

res_df = laptops_i7i9_amz('https://www.amazon.in/')

res_df
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Driver [C:\Users\Admin\.wdm\drivers\chromedriver\win32\87.0.4280.88\chromedriver.exe] found in cache
# <ipython-input-284-ae1b2fec079a>:4: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=opts)
#                                                 title     price  \
# 0   (Renewed) Lenovo ThinkPad High Performance 12....    36,999
# 1   (Renewed) HP EliteBook FOLIO 9480M Laptop (Cor...    28,490
# 2   HP 14 10th Gen Intel Core i7 Ultra Thin and Li...    71,408
# 3   ASUS ZenBook 14 (2020) Intel Core i7-1165G7 11...    96,809
# 4   HP Pavilion x360 Core i7 8th Gen 14-inch Touch...    82,990
# ..                                                ...       ...
# 95  DELL INSPIRON 7490 (C567502WIN9) CORE I7 10TH ...  1,19,990
# 96  Dell Latitude 3410 || 10th Generation Intel Co...    89,990
# 97  (Renewed) HP Pavilion 15-CS1052TX 2018 15.6-in...    58,990
# 98  2019 HP ProBook 450 G6 15.6" FHD Full HD (1920...         ?
# 99  Dell Inspiron 15 G3 3500 Gaming Laptop (10th G...    99,980
#
#                ratings
# 0   4.1 out of 5 stars
# 1            Not_rated
# 2   3.2 out of 5 stars
# 3   5.0 out of 5 stars
# 4   4.1 out of 5 stars
# ..                 ...
# 95  4.0 out of 5 stars
# 96           Not_rated
# 97  1.0 out of 5 stars
# 98  3.3 out of 5 stars
# 99  4.0 out of 5 stars
#
# [100 rows x 3 columns]

# %%
df.to_csv('100_laptops_amz.csv',index=None)

# %% [markdown]
# #### .    <!---EOF ---!>
